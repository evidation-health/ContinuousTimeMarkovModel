# %%
# %matplotlib inline
import pylab as plt
import sys
sys.path.append('../lib')
from etl.data_io import read_file

plt.style.use('ggplot')

DATA_DIR = '../data/'
filename = 'COPD.csv.gz'

# %%
df = read_file("%s/%s" % (DATA_DIR, filename))

# Histogram of timestamps
df.Timestamp.hist(bins = 20)

# %%
# Histogram of First Onset Time
df.FirstOnsetTime.hist(bins = 20)
